# %%
# Notebook 01: Fetch PubMed abstracts for multiple categories

import pickle
import time
import os
from Bio import Entrez

# ----------------------------
# 1️⃣ Setup
# ----------------------------
Entrez.email = "pranav4official@gmail.com"  # Required by NCBI

# Categories with ~25 terms each
search_categories = {
    "diseases": [
        "diabetes", "hypertension", "cancer", "asthma", "tuberculosis",
        "HIV", "malaria", "arthritis", "osteoporosis", "obesity",
        "stroke", "Alzheimer's disease", "Parkinson's disease", "hepatitis",
        "migraine", "anemia", "COVID-19", "influenza", "cholera",
        "dengue", "epilepsy", "schizophrenia", "depression", "thyroid disorder",
        "kidney disease"
    ],
    "symptoms": [
        "fever", "cough", "headache", "fatigue", "chest pain",
        "shortness of breath", "dizziness", "nausea", "vomiting", "diarrhea",
        "constipation", "joint pain", "back pain", "sore throat",
        "weight loss", "weight gain", "loss of appetite", "night sweats",
        "itching", "blurred vision", "memory loss", "insomnia",
        "anxiety", "rash", "swelling"
    ],
    "medicines": [
        "aspirin", "paracetamol", "ibuprofen", "amoxicillin", "metformin",
        "statins", "insulin", "omeprazole", "azithromycin", "chloroquine",
        "hydroxychloroquine", "dexamethasone", "morphine", "codeine",
        "heparin", "warfarin", "atenolol", "losartan", "amlodipine",
        "levothyroxine", "diazepam", "sertraline", "fluoxetine",
        "acetaminophen", "naproxen"
    ],
    "procedures": [
        "MRI", "CT scan", "X-ray", "ultrasound", "colonoscopy",
        "endoscopy", "angioplasty", "dialysis", "chemotherapy",
        "radiotherapy", "immunotherapy", "surgery", "biopsy",
        "laparoscopy", "echocardiography", "blood transfusion",
        "bone marrow transplant", "pacemaker implantation",
        "stent placement", "cesarean section", "vaccination",
        "organ transplantation", "plastic surgery", "cataract surgery",
        "hip replacement"
    ],
    "human_systems": [
        "nervous system", "circulatory system", "respiratory system",
        "digestive system", "urinary system", "reproductive system",
        "endocrine system", "skeletal system", "muscular system",
        "immune system", "integumentary system", "lymphatic system",
        "central nervous system", "autonomic nervous system",
        "vascular system", "renal system", "gastrointestinal system",
        "cardiovascular system", "pulmonary system", "hepatic system",
        "pancreatic system", "ocular system", "auditory system",
        "olfactory system", "connective tissues"
    ],
    "miscellaneous": [
        "placebo", "genome", "epigenetics", "stem cells", "CRISPR",
        "nanomedicine", "microbiome", "biomarkers", "artificial intelligence",
        "machine learning", "precision medicine", "telemedicine",
        "bioinformatics", "metabolomics", "proteomics", "genomics",
        "nutrigenomics", "clinical trials", "public health", "epidemiology",
        "medical ethics", "healthcare policy", "drug resistance",
        "vaccine hesitancy", "personalized therapy"
    ]
}

max_results_per_term = 10   # keep small for testing
save_folder = "./abstracts_by_category/"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

# ----------------------------
# 2️⃣ Function to fetch abstracts
# ----------------------------
def fetch_pubmed_abstracts(term, max_results=10):
    abstracts = []
    try:
        handle = Entrez.esearch(db="pubmed", term=term, retmax=max_results)
        record = Entrez.read(handle)
        handle.close()
        ids = record["IdList"]
        
        for pubmed_id in ids:
            try:
                fetch_handle = Entrez.efetch(db="pubmed", id=pubmed_id, rettype="abstract", retmode="text")
                abstract_text = fetch_handle.read()
                fetch_handle.close()
                abstracts.append(abstract_text.strip())
                time.sleep(0.1)  # polite delay
            except Exception as e_inner:
                print(f"Failed to fetch {pubmed_id}: {e_inner}")
    except Exception as e_outer:
        print(f"Search failed for {term}: {e_outer}")
    
    return abstracts

# ----------------------------
# 3️⃣ Loop over categories & terms
# ----------------------------
all_abstracts = {}

for category, terms in search_categories.items():
    print(f"\n📂 Category: {category}")
    category_file = os.path.join(save_folder, f"{category}_abstracts.pkl")
    category_abstracts = {}
    
    # Skip if already exists
    if os.path.exists(category_file):
        print(f"✅ Already saved for {category}, loading...")
        with open(category_file, "rb") as f:
            category_abstracts = pickle.load(f)
    else:
        for term in terms:
            print(f"   🔎 Fetching abstracts for: {term}")
            abstracts = fetch_pubmed_abstracts(term, max_results=max_results_per_term)
            category_abstracts[term] = abstracts
            print(f"   ✅ {len(abstracts)} abstracts saved for {term}")
        
        with open(category_file, "wb") as f:
            pickle.dump(category_abstracts, f)
    
    all_abstracts[category] = category_abstracts

# ----------------------------
# 4️⃣ Save everything together (optional)
# ----------------------------
all_file = os.path.join(save_folder, "all_pubmed_abstracts.pkl")
with open(all_file, "wb") as f:
    pickle.dump(all_abstracts, f)

print("\n🎉 All abstracts fetched and saved by category.")
# Out:
# 📂 Category: diseases
#    🔎 Fetching abstracts for: diabetes
#    ✅ 10 abstracts saved for diabetes
#    🔎 Fetching abstracts for: hypertension
#    ✅ 10 abstracts saved for hypertension
#    🔎 Fetching abstracts for: cancer
#    ✅ 10 abstracts saved for cancer
#    🔎 Fetching abstracts for: asthma
#    ✅ 10 abstracts saved for asthma
#    🔎 Fetching abstracts for: tuberculosis
#    ✅ 10 abstracts saved for tuberculosis
#    🔎 Fetching abstracts for: HIV
#    ✅ 10 abstracts saved for HIV
#    🔎 Fetching abstracts for: malaria
#    ✅ 10 abstracts saved for malaria
#    🔎 Fetching abstracts for: arthritis
#    ✅ 10 abstracts saved for arthritis
#    🔎 Fetching abstracts for: osteoporosis
#    ✅ 10 abstracts saved for osteoporosis
#    🔎 Fetching abstracts for: obesity
#    ✅ 10 abstracts saved for obesity
#    🔎 Fetching abstracts for: stroke
#    ✅ 10 abstracts saved for stroke
#    🔎 Fetching abstracts for: Alzheimer's disease
#    ✅ 10 abstracts saved for Alzheimer's disease
#    🔎 Fetching abstracts for: Parkinson's disease
#    ✅ 10 abstracts saved for Parkinson's disease
#    🔎 Fetching abstracts for: hepatitis
#    ✅ 10 abstracts saved for hepatitis
#    🔎 Fetching abstracts for: migraine
#    ✅ 10 abstracts saved for migraine
#    🔎 Fetching abstracts for: anemia
#    ✅ 10 abstracts saved for anemia
#    🔎 Fetching abstracts for: COVID-19
#    ✅ 10 abstracts saved for COVID-19
#    🔎 Fetching abstracts for: influenza
#    ✅ 10 abstracts saved for influenza
#    🔎 Fetching abstracts for: cholera
#    ✅ 10 abstracts saved for cholera
#    🔎 Fetching abstracts for: dengue
#    ✅ 10 abstracts saved for dengue
#    🔎 Fetching abstracts for: epilepsy
#    ✅ 10 abstracts saved for epilepsy
#    🔎 Fetching abstracts for: schizophrenia
#    ✅ 10 abstracts saved for schizophrenia
#    🔎 Fetching abstracts for: depression
#    ✅ 10 abstracts saved for depression
#    🔎 Fetching abstracts for: thyroid disorder
#    ✅ 10 abstracts saved for thyroid disorder
#    🔎 Fetching abstracts for: kidney disease
#    ✅ 10 abstracts saved for kidney disease
#
# 📂 Category: symptoms
#    🔎 Fetching abstracts for: fever
#    ✅ 10 abstracts saved for fever
#    🔎 Fetching abstracts for: cough
#    ✅ 10 abstracts saved for cough
#    🔎 Fetching abstracts for: headache
#    ✅ 10 abstracts saved for headache
#    🔎 Fetching abstracts for: fatigue
#    ✅ 10 abstracts saved for fatigue
#    🔎 Fetching abstracts for: chest pain
#    ✅ 10 abstracts saved for chest pain
#    🔎 Fetching abstracts for: shortness of breath
#    ✅ 10 abstracts saved for shortness of breath
#    🔎 Fetching abstracts for: dizziness
#    ✅ 10 abstracts saved for dizziness
#    🔎 Fetching abstracts for: nausea
#    ✅ 10 abstracts saved for nausea
#    🔎 Fetching abstracts for: vomiting
#    ✅ 10 abstracts saved for vomiting
#    🔎 Fetching abstracts for: diarrhea
#    ✅ 10 abstracts saved for diarrhea
#    🔎 Fetching abstracts for: constipation
#    ✅ 10 abstracts saved for constipation
#    🔎 Fetching abstracts for: joint pain
#    ✅ 10 abstracts saved for joint pain
#    🔎 Fetching abstracts for: back pain
#    ✅ 10 abstracts saved for back pain
#    🔎 Fetching abstracts for: sore throat
#    ✅ 10 abstracts saved for sore throat
#    🔎 Fetching abstracts for: weight loss
#    ✅ 10 abstracts saved for weight loss
#    🔎 Fetching abstracts for: weight gain
#    ✅ 10 abstracts saved for weight gain
#    🔎 Fetching abstracts for: loss of appetite
#    ✅ 10 abstracts saved for loss of appetite
#    🔎 Fetching abstracts for: night sweats
#    ✅ 10 abstracts saved for night sweats
#    🔎 Fetching abstracts for: itching
#    ✅ 10 abstracts saved for itching
#    🔎 Fetching abstracts for: blurred vision
#    ✅ 10 abstracts saved for blurred vision
#    🔎 Fetching abstracts for: memory loss
#    ✅ 10 abstracts saved for memory loss
#    🔎 Fetching abstracts for: insomnia
#    ✅ 10 abstracts saved for insomnia
#    🔎 Fetching abstracts for: anxiety
#    ✅ 10 abstracts saved for anxiety
#    🔎 Fetching abstracts for: rash
#    ✅ 10 abstracts saved for rash
#    🔎 Fetching abstracts for: swelling
#    ✅ 10 abstracts saved for swelling
#
# 📂 Category: medicines
#    🔎 Fetching abstracts for: aspirin
#    ✅ 10 abstracts saved for aspirin
#    🔎 Fetching abstracts for: paracetamol
#    ✅ 10 abstracts saved for paracetamol
#    🔎 Fetching abstracts for: ibuprofen
#    ✅ 10 abstracts saved for ibuprofen
#    🔎 Fetching abstracts for: amoxicillin
#    ✅ 10 abstracts saved for amoxicillin
#    🔎 Fetching abstracts for: metformin
#    ✅ 10 abstracts saved for metformin
#    🔎 Fetching abstracts for: statins
#    ✅ 10 abstracts saved for statins
#    🔎 Fetching abstracts for: insulin
#    ✅ 10 abstracts saved for insulin
#    🔎 Fetching abstracts for: omeprazole
#    ✅ 10 abstracts saved for omeprazole
#    🔎 Fetching abstracts for: azithromycin
#    ✅ 10 abstracts saved for azithromycin
#    🔎 Fetching abstracts for: chloroquine
#    ✅ 10 abstracts saved for chloroquine
#    🔎 Fetching abstracts for: hydroxychloroquine
#    ✅ 10 abstracts saved for hydroxychloroquine
#    🔎 Fetching abstracts for: dexamethasone
#    ✅ 10 abstracts saved for dexamethasone
#    🔎 Fetching abstracts for: morphine
#    ✅ 10 abstracts saved for morphine
#    🔎 Fetching abstracts for: codeine
#    ✅ 10 abstracts saved for codeine
#    🔎 Fetching abstracts for: heparin
#    ✅ 10 abstracts saved for heparin
#    🔎 Fetching abstracts for: warfarin
#    ✅ 10 abstracts saved for warfarin
#    🔎 Fetching abstracts for: atenolol
#    ✅ 10 abstracts saved for atenolol
#    🔎 Fetching abstracts for: losartan
#    ✅ 10 abstracts saved for losartan
#    🔎 Fetching abstracts for: amlodipine
#    ✅ 10 abstracts saved for amlodipine
#    🔎 Fetching abstracts for: levothyroxine
#    ✅ 10 abstracts saved for levothyroxine
#    🔎 Fetching abstracts for: diazepam
#    ✅ 10 abstracts saved for diazepam
#    🔎 Fetching abstracts for: sertraline
#    ✅ 10 abstracts saved for sertraline
#    🔎 Fetching abstracts for: fluoxetine
#    ✅ 10 abstracts saved for fluoxetine
#    🔎 Fetching abstracts for: acetaminophen
#    ✅ 10 abstracts saved for acetaminophen
#    🔎 Fetching abstracts for: naproxen
#    ✅ 10 abstracts saved for naproxen
#
# 📂 Category: procedures
#    🔎 Fetching abstracts for: MRI
#    ✅ 10 abstracts saved for MRI
#    🔎 Fetching abstracts for: CT scan
#    ✅ 10 abstracts saved for CT scan
#    🔎 Fetching abstracts for: X-ray
#    ✅ 10 abstracts saved for X-ray
#    🔎 Fetching abstracts for: ultrasound
#    ✅ 10 abstracts saved for ultrasound
#    🔎 Fetching abstracts for: colonoscopy
#    ✅ 10 abstracts saved for colonoscopy
#    🔎 Fetching abstracts for: endoscopy
#    ✅ 10 abstracts saved for endoscopy
#    🔎 Fetching abstracts for: angioplasty
#    ✅ 10 abstracts saved for angioplasty
#    🔎 Fetching abstracts for: dialysis
#    ✅ 10 abstracts saved for dialysis
#    🔎 Fetching abstracts for: chemotherapy
#    ✅ 10 abstracts saved for chemotherapy
#    🔎 Fetching abstracts for: radiotherapy
#    ✅ 10 abstracts saved for radiotherapy
#    🔎 Fetching abstracts for: immunotherapy
#    ✅ 10 abstracts saved for immunotherapy
#    🔎 Fetching abstracts for: surgery
#    ✅ 10 abstracts saved for surgery
#    🔎 Fetching abstracts for: biopsy
#    ✅ 10 abstracts saved for biopsy
#    🔎 Fetching abstracts for: laparoscopy
#    ✅ 10 abstracts saved for laparoscopy
#    🔎 Fetching abstracts for: echocardiography
#    ✅ 10 abstracts saved for echocardiography
#    🔎 Fetching abstracts for: blood transfusion
#    ✅ 10 abstracts saved for blood transfusion
#    🔎 Fetching abstracts for: bone marrow transplant
#    ✅ 10 abstracts saved for bone marrow transplant
#    🔎 Fetching abstracts for: pacemaker implantation
#    ✅ 10 abstracts saved for pacemaker implantation
#    🔎 Fetching abstracts for: stent placement
#    ✅ 10 abstracts saved for stent placement
#    🔎 Fetching abstracts for: cesarean section
#    ✅ 10 abstracts saved for cesarean section
#    🔎 Fetching abstracts for: vaccination
#    ✅ 10 abstracts saved for vaccination
#    🔎 Fetching abstracts for: organ transplantation
#    ✅ 10 abstracts saved for organ transplantation
#    🔎 Fetching abstracts for: plastic surgery
#    ✅ 10 abstracts saved for plastic surgery
#    🔎 Fetching abstracts for: cataract surgery
#    ✅ 10 abstracts saved for cataract surgery
#    🔎 Fetching abstracts for: hip replacement
#    ✅ 10 abstracts saved for hip replacement
#
# 📂 Category: human_systems
#    🔎 Fetching abstracts for: nervous system
#    ✅ 10 abstracts saved for nervous system
#    🔎 Fetching abstracts for: circulatory system
#    ✅ 10 abstracts saved for circulatory system
#    🔎 Fetching abstracts for: respiratory system
#    ✅ 10 abstracts saved for respiratory system
#    🔎 Fetching abstracts for: digestive system
#    ✅ 10 abstracts saved for digestive system
#    🔎 Fetching abstracts for: urinary system
#    ✅ 10 abstracts saved for urinary system
#    🔎 Fetching abstracts for: reproductive system
#    ✅ 10 abstracts saved for reproductive system
#    🔎 Fetching abstracts for: endocrine system
#    ✅ 10 abstracts saved for endocrine system
#    🔎 Fetching abstracts for: skeletal system
#    ✅ 10 abstracts saved for skeletal system
#    🔎 Fetching abstracts for: muscular system
#    ✅ 10 abstracts saved for muscular system
#    🔎 Fetching abstracts for: immune system
#    ✅ 10 abstracts saved for immune system
#    🔎 Fetching abstracts for: integumentary system
#    ✅ 10 abstracts saved for integumentary system
#    🔎 Fetching abstracts for: lymphatic system
#    ✅ 10 abstracts saved for lymphatic system
#    🔎 Fetching abstracts for: central nervous system
#    ✅ 10 abstracts saved for central nervous system
#    🔎 Fetching abstracts for: autonomic nervous system
#    ✅ 10 abstracts saved for autonomic nervous system
#    🔎 Fetching abstracts for: vascular system
#    ✅ 10 abstracts saved for vascular system
#    🔎 Fetching abstracts for: renal system
#    ✅ 10 abstracts saved for renal system
#    🔎 Fetching abstracts for: gastrointestinal system
#    ✅ 10 abstracts saved for gastrointestinal system
#    🔎 Fetching abstracts for: cardiovascular system
#    ✅ 10 abstracts saved for cardiovascular system
#    🔎 Fetching abstracts for: pulmonary system
#    ✅ 10 abstracts saved for pulmonary system
#    🔎 Fetching abstracts for: hepatic system
#    ✅ 10 abstracts saved for hepatic system
#    🔎 Fetching abstracts for: pancreatic system
#    ✅ 10 abstracts saved for pancreatic system
#    🔎 Fetching abstracts for: ocular system
#    ✅ 10 abstracts saved for ocular system
#    🔎 Fetching abstracts for: auditory system
#    ✅ 10 abstracts saved for auditory system
#    🔎 Fetching abstracts for: olfactory system
#    ✅ 10 abstracts saved for olfactory system
#    🔎 Fetching abstracts for: connective tissues
#    ✅ 10 abstracts saved for connective tissues
#
# 📂 Category: miscellaneous
#    🔎 Fetching abstracts for: placebo
#    ✅ 10 abstracts saved for placebo
#    🔎 Fetching abstracts for: genome
#    ✅ 10 abstracts saved for genome
#    🔎 Fetching abstracts for: epigenetics
#    ✅ 10 abstracts saved for epigenetics
#    🔎 Fetching abstracts for: stem cells
#    ✅ 10 abstracts saved for stem cells
#    🔎 Fetching abstracts for: CRISPR
#    ✅ 10 abstracts saved for CRISPR
#    🔎 Fetching abstracts for: nanomedicine
#    ✅ 10 abstracts saved for nanomedicine
#    🔎 Fetching abstracts for: microbiome
#    ✅ 10 abstracts saved for microbiome
#    🔎 Fetching abstracts for: biomarkers
#    ✅ 10 abstracts saved for biomarkers
#    🔎 Fetching abstracts for: artificial intelligence
#    ✅ 10 abstracts saved for artificial intelligence
#    🔎 Fetching abstracts for: machine learning
#    ✅ 10 abstracts saved for machine learning
#    🔎 Fetching abstracts for: precision medicine
#    ✅ 10 abstracts saved for precision medicine
#    🔎 Fetching abstracts for: telemedicine
#    ✅ 10 abstracts saved for telemedicine
#    🔎 Fetching abstracts for: bioinformatics
#    ✅ 10 abstracts saved for bioinformatics
#    🔎 Fetching abstracts for: metabolomics
#    ✅ 10 abstracts saved for metabolomics
#    🔎 Fetching abstracts for: proteomics
#    ✅ 10 abstracts saved for proteomics
#    🔎 Fetching abstracts for: genomics
#    ✅ 10 abstracts saved for genomics
#    🔎 Fetching abstracts for: nutrigenomics
#    ✅ 10 abstracts saved for nutrigenomics
#    🔎 Fetching abstracts for: clinical trials
#    ✅ 10 abstracts saved for clinical trials
#    🔎 Fetching abstracts for: public health
#    ✅ 10 abstracts saved for public health
#    🔎 Fetching abstracts for: epidemiology
#    ✅ 10 abstracts saved for epidemiology
#    🔎 Fetching abstracts for: medical ethics
#    ✅ 10 abstracts saved for medical ethics
#    🔎 Fetching abstracts for: healthcare policy
#    ✅ 10 abstracts saved for healthcare policy
#    🔎 Fetching abstracts for: drug resistance
#    ✅ 10 abstracts saved for drug resistance
#    🔎 Fetching abstracts for: vaccine hesitancy
#    ✅ 10 abstracts saved for vaccine hesitancy
#    🔎 Fetching abstracts for: personalized therapy
#    ✅ 10 abstracts saved for personalized therapy
#
# 🎉 All abstracts fetched and saved by category.
